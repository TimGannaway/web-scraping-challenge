# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pymongo
import datetime
import requests
import pandas as pd

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
conn = 'mongodb://localhost:27017'
# conn = 'mongodb://USERNAME:PASSWORD@HOST:PORT'
client = pymongo.MongoClient(conn)

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - ====== WebDriver manager ======
# INFO:WDM:====== WebDriver manager ======
# [WDM] - Current google-chrome version is 102.0.5005
# INFO:WDM:Current google-chrome version is 102.0.5005
# [WDM] - Get LATEST chromedriver version for 102.0.5005 google-chrome
# INFO:WDM:Get LATEST chromedriver version for 102.0.5005 google-chrome
# [WDM] - Driver [C:\Users\TimothyGannaway\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# INFO:WDM:Driver [C:\Users\TimothyGannaway\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache

# %%
url = 'https://redplanetscience.com/'
browser.visit(url)

# %%
# Iterate through all pages
for x in range(50):
    # HTML object
    html = browser.html
    # Parse HTML with Beautiful Soup
    soup = BeautifulSoup(html, 'html.parser')
    # Retrieve all elements that contain book information
    articles = soup.find_all('div', class_='list_text')

    # Iterate through each book
    for article in articles:
        # Use Beautiful Soup's find() method to navigate and retrieve attributes
        # content_title = article.find('content_title')
        content_title = article.find('div', class_='content_title').text.strip()
        article_teaser_body = article.find('div', class_='article_teaser_body').text.strip()
        # link = h3.find('a')
        # href = link['href']
        # title = link['title']
        print('-----------')
        print(content_title)
        print(article_teaser_body)
        # print('http://books.toscrape.com/' + href)

    # Click the 'Next' button on each page
    # try:
    #     browser.links.find_by_partial_text('next').click()
          
    # except:
    #   print("Scraping Complete")
# Out:
# -----------
# Sensors on Mars 2020 Spacecraft Answer Long-Distance Call From Earth
# Instruments tailored to collect data during the descent of NASA's next rover through the Red Planet's atmosphere have been checked in flight.
# -----------
# NASA's Mars 2020 Rover Tests Descent-Stage Separation
# A crane lifts the rocket-powered descent stage away from NASA's Mars 2020 rover after technicians tested the pyrotechnic charges that separate the two spacecraft.
# -----------
# 6 Things to Know About NASA's Ingenuity Mars Helicopter
# The first helicopter attempting to fly on another planet is a marvel of engineering. Get up to speed with these key facts about its plans.
# -----------
# MAVEN Maps Electric Currents around Mars that are Fundamental to Atmospheric Loss
# Five years after NASA’s MAVEN spacecraft entered into orbit around Mars, data from the mission has led to the creation of a map of electric current systems in the Martian atmosphere.
# -----------
# ...

# %%
############ browser.quit()

# %%
url = 'https://spaceimages-mars.com'
browser.visit(url)

# %%
# Navigate to the featured image 

browser.links.find_by_partial_text('FULL').click()

# %%
featured_img_link = browser.links.find_by_partial_href('featured').first
featured_img_link['href']
# Out:
# 'https://spaceimages-mars.com/image/featured/mars3.jpg'

# %%
url = 'https://galaxyfacts-mars.com/'
browser.visit(url)

# %%
df = pd.DataFrame()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\TIMOTH~1\AppData\Local\Temp/ipykernel_5496/1928837447.py in <module>
# ----> 1 df = pd.DataFrame()
#
# NameError: name 'pd' is not defined

# %%
##  https://galaxyfacts-mars.com/

# Iterate through galaxy facts table

# HTML object
html = browser.html
# Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')
# Retrieve all elements that contain book information
articles = soup.find_all('tr')
# Iterate through each book
for article in articles:
    # Use Beautiful Soup's find() method to navigate and retrieve attributes
    content_title = article.find('th').text.strip()
    content_text = article.find('td').text.strip()
    print('-----------')
    print(content_title)
    print(content_text)
    # print('http://books.toscrape.com/' + href)

    # Click the 'Next' button on each page
    # try:
    #     browser.links.find_by_partial_text('next').click()
          
    # except:
    #   print("Scraping Complete")
# Out:
# -----------
# Mars - Earth Comparison
# Mars
# -----------
# Diameter:
# 6,779 km
# -----------
# Mass:
# 6.39 × 10^23 kg
# -----------
# Moons:
# 2
# -----------
# Distance from Sun:
# 227,943,824 km
# -----------
# Length of Year:
# 687 Earth days
# -----------
# Temperature:
# -87 to -5 °C
# -----------
# Equatorial Diameter:
# 6,792 km
# -----------
# Polar Diameter:
# 6,752 km
# -----------
# Mass:
# 6.39 × 10^23 kg (0.11 Earths)
# -----------
# Moons:
# 2 ( Phobos  &  Deimos )
# -----------
# Orbit Distance:
# 227,943,824 km (1.38 AU)
# -----------
# Orbit Period:
# 687 days (1.9 years)
# -----------
# Surface Temperature:
# -87 to -5 °C
# -----------
# First Record:
# 2nd millennium BC
# -----------
# Recorded By:
# Egyptian astronomers

# %%
browser.quit()
